# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification

from logistic_classifier import LogisticClassifier
get_ipython().run_line_magic('load_ext', 'autoreload')
get_ipython().run_line_magic('autoreload', '2')

# %%
X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5, n_classes=3, random_state=1)

# %%
model = LogisticClassifier()
model.fit(X, y, epochs=500)
y_pred, acc = model.predict(X, y)
print("Accuracy:", acc)
# Out:
# Accuracy: 0.666

# %%
model.probabs
# Out:
# array([[0.08675202, 0.45242436, 0.84556903],
#        [0.50355078, 0.08023361, 0.19219359],
#        [0.34236008, 0.49058394, 0.01987022],
#        ...,
#        [0.17290207, 0.74857612, 0.57812413],
#        [0.03669929, 0.2151426 , 0.982299  ],
#        [0.64875256, 0.74101726, 0.00114678]])

# %%
plt.plot(y.reshape(-1,1), '.')
plt.plot(y_pred.reshape(-1,1), '.')

# %%
for i in range(model.num_classes):
    plt.figure(figsize=(16,6))
    plt.subplot(1, 2, 1)
    plt.plot(model.acc_history[i])
    plt.grid()
    plt.subplot(1, 2, 2)
    plt.plot(model.loss_history[i])
    plt.grid()
    plt.show()
